# %%
import cf
import cfplot as cfp
import matplotlib.pyplot as plt
import os

# %%
# %matplotlib inline

# %%
obj[0][0]
# Out:
# <CF Field: surface_temperature(time(1), latitude(324), longitude(432)) K>

# %%
cfp.con(obj[0][0])

plt.show();

# %%
base_path = '/gws/nopw/j04/canari/shared/large-ensemble/priority/HIST1/5/ATM/yearly/1850/'
files = ['cv247a_5_mon_m01s00i024_3.nc', 'cv247a_5_mon_m01s03i236_8.nc']

full_paths = [os.path.join(base_path, f) for f in files]

obj = cf.read(full_paths, cfa_write='./my_dataset.cfa')

cf.write(obj, './my_dataset.cfa', 
         # cfa='field'
        )
